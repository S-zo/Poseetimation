# %%
import os

file_path = "C:/Users/Admin/Desktop/framesave/stand"
file_names = os.listdir(file_path)

i = 1
for file_name in file_names:
    src = os.path.join(file_path, file_name)
    num = ("%05d" % i)
    dst = str(num) + '.jpg'
    dst = os.path.join(file_path, dst)
    os.rename(src, dst)
    i+=1q

# %%
# %cd C:/Users/Admin/Desktop/tfestimation/Realtime-Action-Recognition-master
# !python src/s5_test.py -m model/byun.pickle -t video -p poseestimation.mp4
# Out:
# 7 19:23:11,456] [TfPoseEstimator] [DEBUG] inference+ original shape=1920x1080
# [2021-05-07 19:23:11,456] [TfPoseEstimator] [DEBUG] inference+ original shape=1920x1080
# 2021-05-07 19:23:11,456 DEBUG inference+ original shape=1920x1080
# [2021-05-07 19:23:11,753] [TfPoseEstimator] [DEBUG] inference- heatMat=328x184 pafMat=328x184
# [2021-05-07 19:23:11,753] [TfPoseEstimator] [DEBUG] inference- heatMat=328x184 pafMat=328x184
# 2021-05-07 19:23:11,753 DEBUG inference- heatMat=328x184 pafMat=328x184
# [2021-05-07 19:23:11,755] [TfPoseEstimator] [DEBUG] estimate time=0.00206
# [2021-05-07 19:23:11,755] [TfPoseEstimator] [DEBUG] estimate time=0.00206
# 2021-05-07 19:23:11,755 DEBUG estimate time=0.00206
# [2021-05-07 19:23:11,755] [TfPoseEstimator] [INFO] inference image in 0.2996 seconds.
# [2021-05-07 19:23:11,755] [TfPoseEstimator] [INFO] inference image in 0.2996 seconds.
# 2021-05-07 19:23:11,755 INFO inference image in 0.2996 seconds.
# ...

# %%
# %cd C:/Users/Admin/Desktop/tfestimation/Realtime-Action-Recognition-master
# !python src/s5_test.py -m model/byun.pickle -t webcam
# Out:
# C:\Users\Admin\Desktop\tfestimation\Realtime-Action-Recognition-master
# ^C
